# %%
token = "mo-kWW7Jjyq1-bjAM6OrAhQcz1z7YsJB8IpS6BkY3YB6XazSAC-81jWW3wnv2294"

# %%
from hs_udata import *
from datetime import datetime

# %%
set_token(token)

# %%
data = stock_list()

# %%
data.head()
# Out:
#   secu_abbr        chi_name listed_state secu_code secu_market listed_sector  \
# 0      平安银行      平安银行股份有限公司           上市    000001     深圳证券交易所            主板
# 1     万  科Ａ      万科企业股份有限公司           上市    000002     深圳证券交易所            主板
# 2     PT金田Ａ  金田实业(集团)股份有限公司           终止    000003     深圳证券交易所            主板
# 3      国华网安  深圳国华网安科技股份有限公司           上市    000004     深圳证券交易所            主板
# 4    ST 星 源    深圳世纪星源股份有限公司           上市    000005     深圳证券交易所            主板
#
#      hs_code
# 0  000001.SZ
# 1  000002.SZ
# 2  000003.SZ
# 3  000004.SZ
# 4  000005.SZ

# %%
data = fut_quote_minute(
    en_prod_code = "IF2110.CFE",
    begin_date="2021-09-01",
    end_date="2021-09-30"
)

# %%
data
# Out:
#             date change_pct       high  amount  turnover_volume        low  \
# 0     2021-09-01    -0.1177  4761.2000    4756               79  4745.4000
# 1     2021-09-01    -0.1852  4752.6000    4740               25  4743.8000
# 2     2021-09-01    -0.2361  4743.8000    4726               25  4732.4000
# 3     2021-09-01     0.0465  4735.0000    4705               40  4728.0000
# 4     2021-09-01    -0.0549  4735.8000    4694               30  4730.8000
# ...          ...        ...        ...     ...              ...        ...
# 3355  2021-09-22    -0.0499  4813.8000   87457              427  4811.0000
# 3356  2021-09-22    -0.0416  4812.0000   87729              505  4809.0000
# 3357  2021-09-22     0.0707  4813.4000   88137              634  4808.6000
# 3358  2021-09-22     0.0457  4814.8000   88491              564  4812.4000
# 3359  2021-09-22     0.0000  4814.6000   88491                0  4814.6000
#
#         change  turnover_value  time      close       open
# ...

# %%
fut_list()
# Out:
#          secu_abbr secu_code    gil_code
# 0          沪原油2112    SC2112  SC2112.INE
# 1          沪原油2203    SC2203  SC2203.INE
# 2          沪原油2206    SC2206  SC2206.INE
# 3          沪原油2209    SC2209  SC2209.INE
# 4          沪原油2212    SC2212  SC2212.INE
# ..             ...       ...         ...
# 651    5年期国债期货2206    TF2206  TF2206.CFE
# 652    2年期国债期货2206    TS2206  TS2206.CFE
# 653  中证500股指期货2111    IC2111  IC2111.CFE
# 654  沪深300股指期货2111    IF2111  IF2111.CFE
# 655   上证50股指期货2111    IH2111  IH2111.CFE
#
# [656 rows x 3 columns]
